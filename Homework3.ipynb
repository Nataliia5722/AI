# %% [markdown]
# <a href="https://colab.research.google.com/github/Nataliia5722/AI/blob/main/Homework3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# https://www.kaggle.com/c/titanic

# %%
data = pd.read_csv('https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/fa71405126017e6a37bea592440b4bee94bf7b9e/titanic.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# - PassengerId: unique id number to each passenger
# - Survived: passenger survive(1) or died(0) - target
# - Pclass: passenger class
# - Name: name
# - Sex: gender of passenger
# - Age: age of passenger
# - SibSp: number of siblings/spouses
# - Parch: number of parents/children
# - Ticket: ticket number
# - Fare: amount of money spent on ticket
# - Cabin: cabin category
# - Embarked: port where passenger embarked (C = Cherbourg, Q = Queenstown, S = Southampton)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data["SibSp"].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
data["Parch"].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
data["Cabin"].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %% [markdown]
# ### Categorica data

# %%
category=["Survived","Sex","Pclass","Embarked","SibSp","Parch"]

# %%
plt.rcParams['figure.figsize']=(10,10)
sns.countplot(data['Pclass'])
plt.xticks(rotation=45)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived',data=data,ax=ax[1])
ax[1].set_title('Survived')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### Analyze Sex& Survived

# %%
data.groupby(['Sex','Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Pclass & Survivedю Завдання 1
# - знайти розподіл виживших відносно рівня кают

# %%
### your code
#sns.barplot(x='Pclass', y='Survived', data=data)

def showChart(feature):
    survived = data[data['Survived']==1][feature].value_counts()
    dead = data[data['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived, dead])
    df.index = ['Survived', 'Dead']
    df.plot(kind='bar', stacked=True, figsize=(12,8))

# %%
showChart('Pclass')

# %% [markdown]
# ### Age & Survived

# %%
data['age_group']=data['Age'].apply(lambda x: 'child' if x<18 else( 'young' if (x>=18) and (x< 30) 
                                                                   else( 'middle' if (x>=30) and (x< 60) else 'old'
                                                                       )
                                                                  )
                                   )

# %%
data[['Age','age_group']].head(10)
# Out:
#     Age age_group
# 0  22.0     young
# 1  38.0    middle
# 2  26.0     young
# 3  35.0    middle
# 4  35.0    middle
# 5   NaN       old
# 6  54.0    middle
# 7   2.0     child
# 8  27.0     young
# 9  14.0     child

# %% [markdown]
# ToDo 'Nan' як боротись?

# %%
data['age_group']=data['Age'].apply(lambda x: 'child' if x<18 else( 'young' if (x>=18) and (x< 30) 
                                                                   else( 'middle' if (x>=30) and (x< 60) else (
                                                                   'old' if x>=60 else 'missing')
                                                                       )
                                                                  )
                                   )

# %%
data[['Age','age_group']].head(15)
# Out:
#      Age age_group
# 0   22.0     young
# 1   38.0    middle
# 2   26.0     young
# 3   35.0    middle
# 4   35.0    middle
# 5    NaN   missing
# 6   54.0    middle
# 7    2.0     child
# 8   27.0     young
# 9   14.0     child
# 10   4.0     child
# 11  58.0    middle
# 12  20.0     young
# 13  39.0    middle
# 14  14.0     child

# %% [markdown]
# ### Завдання 2
#
# - знайти розподіл виживших відносно віку

# %%
survived = 'survived'
not_survived = 'not survived'
fig, axes = plt.subplots(nrows=1, ncols=2,figsize=(10, 4))
women = data[data['Sex']=='female']
men = data[data['Sex']=='male']
ax = sns.distplot(women[women['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[0], kde =False)
ax = sns.distplot(women[women['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[0], kde =False)
ax.legend()
ax.set_title('Female')
ax = sns.distplot(men[men['Survived']==1].Age.dropna(), bins=18, label = survived, ax = axes[1], kde = False)
ax = sns.distplot(men[men['Survived']==0].Age.dropna(), bins=40, label = not_survived, ax = axes[1], kde = False)
ax.legend()
_ = ax.set_title('Male')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### SibSp & Survived Завдання 3
#
# - знайти розподіл виживших відносно наявності родичей на Титаніку

# %%
### your code
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['SibSp','Survived']].groupby(['SibSp']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Siblings')
sns.countplot('SibSp',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Number of siblings:Survived vs Dead')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Parch & Survived. Завдання 4
# - знайти розподіл виживших відносно наявності батьків-дітей на Титаніку

# %%
### your code
f,ax=plt.subplots(1,2,figsize=(18,8))
data[['Parch','Survived']].groupby(['Parch']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Parents/Children')
sns.countplot('Parch',hue='Survived',data=data,ax=ax[1])
ax[1].set_title('Parents/Children:Survived vs Dead')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Missing values

# %%
data.columns[data.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# age_group        0
# dtype: int64

# %% [markdown]
# #### Fill Missing Value¶

# %%
data[data["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked age_group
# 61   female  38.0      0      0  113572  80.0   B28      NaN    middle
# 829  female  62.0      0      0  113572  80.0   B28      NaN       old

# %%
data.boxplot(column = "Fare", by = "Embarked")
plt.show()

# %%
data["Embarked"] = data["Embarked"].fillna("C")

# %%
data[data["Embarked"].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, age_group]
# Index: []

# %% [markdown]
# #### Missing Age

# %%
data[data.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html
# https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %%
data.Name.head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
names = data.Name
names
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
name_list = []
for name in names:
    name = name.split(".")  
    name_list.append(name)

# %%
name_list
# Out:
# [['Braund, Mr', ' Owen Harris'],
#  ['Cumings, Mrs', ' John Bradley (Florence Briggs Thayer)'],
#  ['Heikkinen, Miss', ' Laina'],
#  ['Futrelle, Mrs', ' Jacques Heath (Lily May Peel)'],
#  ['Allen, Mr', ' William Henry'],
#  ['Moran, Mr', ' James'],
#  ['McCarthy, Mr', ' Timothy J'],
#  ['Palsson, Master', ' Gosta Leonard'],
#  ['Johnson, Mrs', ' Oscar W (Elisabeth Vilhelmina Berg)'],
#  ['Nasser, Mrs', ' Nicholas (Adele Achem)'],
#  ['Sandstrom, Miss', ' Marguerite Rut'],
#  ['Bonnell, Miss', ' Elizabeth'],
#  ['Saundercock, Mr', ' William Henry'],
#  ['Andersson, Mr', ' Anders Johan'],
#  ['Vestrom, Miss', ' Hulda Amanda Adolfina'],
#  ['Hewlett, Mrs', ' (Mary D Kingcome) '],
#  ['Rice, Master', ' Eugene'],
#  ['Williams, Mr', ' Charles Eugene'],
#  ['Vander Planke, Mrs', ' Julius (Emelia Maria Vandemoortele)'],
#  ['Masselmani, Mrs', ' Fatima'],
#  ['Fynney, Mr', ' Joseph J'],
#  ['Beesley, Mr', ' Lawrence'],
#  ['McGowan, Miss', ' Anna "Annie"'],
# ...

# %%
first_part = []
for words in name_list:
    first_part.append(words[0])

# %%
first_part
# Out:
# ['Braund, Mr',
#  'Cumings, Mrs',
#  'Heikkinen, Miss',
#  'Futrelle, Mrs',
#  'Allen, Mr',
#  'Moran, Mr',
#  'McCarthy, Mr',
#  'Palsson, Master',
#  'Johnson, Mrs',
#  'Nasser, Mrs',
#  'Sandstrom, Miss',
#  'Bonnell, Miss',
#  'Saundercock, Mr',
#  'Andersson, Mr',
#  'Vestrom, Miss',
#  'Hewlett, Mrs',
#  'Rice, Master',
#  'Williams, Mr',
#  'Vander Planke, Mrs',
#  'Masselmani, Mrs',
#  'Fynney, Mr',
#  'Beesley, Mr',
#  'McGowan, Miss',
#  'Sloper, Mr',
#  'Palsson, Miss',
#  'Asplund, Mrs',
#  'Emir, Mr',
#  'Fortune, Mr',
#  "O'Dwyer, Miss",
#  'Todoroff, Mr',
#  'Uruchurtu, Don',
#  'Spencer, Mrs',
#  'Glynn, Miss',
#  'Wheadon, Mr',
#  'Meyer, Mr',
#  'Holverson, Mr',
#  'Mamee, Mr',
#  'Cann, Mr',
#  'Vander Planke, Miss',
#  'Nicola-Yarred, Miss',
#  'Ahlin, Mrs',
#  'Turpin, Mrs',
#  'Kraeff, Mr',
#  'Laroche, Miss',
#  'Devaney, Miss',
#  'Rogers, Mr',
#  'Lennon, Mr',
#  "O'Driscoll, Miss",
#  'Samaan, Mr',
#  'Arnold-Franchi, Mrs',
#  'Panula, Master',
# ...

# %%
gender_list = []
for word in first_part:
    word = word.split(",")
    gender_list.append(word)

# %%
gender_list
# Out:
# [['Braund', ' Mr'],
#  ['Cumings', ' Mrs'],
#  ['Heikkinen', ' Miss'],
#  ['Futrelle', ' Mrs'],
#  ['Allen', ' Mr'],
#  ['Moran', ' Mr'],
#  ['McCarthy', ' Mr'],
#  ['Palsson', ' Master'],
#  ['Johnson', ' Mrs'],
#  ['Nasser', ' Mrs'],
#  ['Sandstrom', ' Miss'],
#  ['Bonnell', ' Miss'],
#  ['Saundercock', ' Mr'],
#  ['Andersson', ' Mr'],
#  ['Vestrom', ' Miss'],
#  ['Hewlett', ' Mrs'],
#  ['Rice', ' Master'],
#  ['Williams', ' Mr'],
#  ['Vander Planke', ' Mrs'],
#  ['Masselmani', ' Mrs'],
#  ['Fynney', ' Mr'],
#  ['Beesley', ' Mr'],
#  ['McGowan', ' Miss'],
#  ['Sloper', ' Mr'],
#  ['Palsson', ' Miss'],
#  ['Asplund', ' Mrs'],
#  ['Emir', ' Mr'],
#  ['Fortune', ' Mr'],
#  ["O'Dwyer", ' Miss'],
#  ['Todoroff', ' Mr'],
#  ['Uruchurtu', ' Don'],
#  ['Spencer', ' Mrs'],
#  ['Glynn', ' Miss'],
#  ['Wheadon', ' Mr'],
#  ['Meyer', ' Mr'],
#  ['Holverson', ' Mr'],
#  ['Mamee', ' Mr'],
#  ['Cann', ' Mr'],
#  ['Vander Planke', ' Miss'],
#  ['Nicola-Yarred', ' Miss'],
#  ['Ahlin', ' Mrs'],
# ...

# %%
genders = []
for gender in gender_list:
    genders.append(gender[-1].strip())

# %%
set(genders)
# Out:
# {'Capt',
#  'Col',
#  'Don',
#  'Dr',
#  'Jonkheer',
#  'Lady',
#  'Major',
#  'Master',
#  'Miss',
#  'Mlle',
#  'Mme',
#  'Mr',
#  'Mrs',
#  'Ms',
#  'Rev',
#  'Sir',
#  'the Countess'}

# %% [markdown]
# ### Завдання 5

# %% [markdown]
# Чи можна, базуючись на `set(genders)` придумати, як заповнити пропущені значення в `Age`? Знайти спосіб заповнення пропущенних значень, можна користуватись додатковими фічами - сімейний склад, наявність дітей тощо...

# %% [markdown]
# Так, заповнити можна, але в результаті інформація може виявитися недостовірною в деяких випадках.
# Якщо заповнювати значення в Age, там де він не вказаний, то схема може бути така: розбивши інформацію по фічам - сімейний склад, кількість дітей, батьків, можна далі вказувати середньостатистичний вік для пасажира, опираючись на статистику по всім пасажирам.

# %% [markdown]
# ### Завдання 6
#
# Знайти додаткові спостереження, подумати про додаткові ознаки, які можна згенерувати, щоб потім можна було їх вікористовувати для прогнозу (Виживе/Загине)

# %% [markdown]
# Для генерації можна було б ще використовувати дані про захворювання кожного з пасажирів, в такому випадку була б можливість провести аналітику, яка в данному випадку змогла показати наскільки стан пасажира, в тому числі емоційний, впливає на подальший хід подій. Проте, так як дана інформація відсутня, даний варіант не підходить.
# Наразі, можна використати дані про розміщення кают. Так як планування корабля відоме і розташування кают також, то, знаючи, з якого боку корабель починає тонути, можна спрогнозувати виживе людина чи ні. Звичайно, пасажир може знаходитись взагалі на іншому боці корабля і інші нюанси, тут можна додати ще одну умову - вік.
